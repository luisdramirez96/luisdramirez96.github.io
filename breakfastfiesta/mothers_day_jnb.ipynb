# %%
import pandas as pd

# read file
df = pd.read_csv('BreakfastFiestaOrderLog_latlong.csv', usecols = ['Cliente', 'Orden', 'Delivery Address', 'Latitude', 'Longitude'], index_col='Cliente')

# remove all orders that will be picked up
df = df[~df['Delivery Address'].isin(['Pickup'])]

# drop blank cells
df = df.dropna()

df = df.head(22)

df
# Out:
#                                 Orden  \
# Cliente
# Dayanis_10                   Combo #7
# Wabyy_                       Combo #4
# Wabyy_                       Combo #4
# eliiizabeth.__      Arreglo de globos
# betsy4513        Multiple (vea notas)
# kevg305                      Combo #5
# _Wilson_world                Combo #2
# Drey_uhhh                    Combo #3
# Drey_uhhh                    Combo #3
# Melisa                       Combo #5
# Melisa                       Combo #5
# Chave1496                    Combo #2
# Denise Nunez                 Combo #5
# Monika Client                Combo #3
# Cindy_x98                    Combo #5
# Cindy_x98                    Combo #5
# Mily Client                  Combo #3
# Claudiadaamn                 Combo #5
# el_pitynq       Combo #5 w/ champagne
# Imi_rguez                    Combo #7
# valenmachp                   Combo #4
# Omayrarod_03                 Combo #7
#
#                                                  Delivery Address   Latitude  \
# Cliente
# Dayanis_10              19341 NW 48th Ct, Miami Gardens, FL 33055  25.949633
# Wabyy_                    5000 W 12th Ct Apt 5, Hialeah, FL 33012  25.867947
# Wabyy_                 18006 NW 24th Pl, Pembroke Pines, FL 33029  25.986615
# eliiizabeth.__                 15900 SW 144th Ct, Miami, FL 33177  25.619406
# betsy4513                    2470 SE 14th Ct, Homestead, FL 33035  25.455880
# kevg305                8461 Dundee Terrace, Miami Lakes, FL 33016  25.909754
# _Wilson_world              11519 SW 236th St, Homestead, FL 33032  25.548208
# Drey_uhhh                      11790 SW 35th Ter, Miami, FL 33175  25.735550
# Drey_uhhh                      12732 SW 68th Ter, Miami, FL 33183  25.702964
# Melisa                            5790 W 13 Ct, Hialeah, FL 33012  25.875042
# Melisa          8423 NW 138th Ter Unit 2801, Miami Lakes, FL 3...  25.899725
# Chave1496                 2150 NW 23rd Ct Apt 4A, Miami, FL 33142  25.796535
# Denise Nunez                     460 E 36th St, Hialeah, FL 33013  25.854878
# Monika Client        17620 NW 78rd Ave Apt 200, Hialeah, FL 33015  25.933772
# Cindy_x98                      11485 SW 49th Ter, Miami, FL 33165  25.721073
# Cindy_x98                      15384 SW 169th Ln, Miami, FL 33187  25.609076
# Mily Client                      242 W 38th St, Hialeah, FL 33012  25.856330
# Claudiadaamn            2211 W 52nd St Apt 206, Hialeah, FL 33016  25.870162
# el_pitynq                14855 SW 57th Ln Apt 12, Miami, FL 33183  25.712640
# Imi_rguez                       1714 W 72nd St, Hialeah, FL 33014  25.887652
# valenmachp                    6238 NW 171st St, Hialeah, FL 33015  25.929102
# Omayrarod_03                      5109 SW 5th St, Miami, FL 33134  25.767088
#
#                 Longitude
# Cliente
# Dayanis_10     -80.280748
# Wabyy_         -80.307920
# Wabyy_         -80.389558
# eliiizabeth.__ -80.427357
# betsy4513      -80.439480
# kevg305        -80.337282
# _Wilson_world  -80.378468
# Drey_uhhh      -80.385851
# Drey_uhhh      -80.399806
# Melisa         -80.310713
# Melisa         -80.337944
# Chave1496      -80.234819
# Denise Nunez   -80.273396
# Monika Client  -80.327272
# Cindy_x98      -80.381112
# Cindy_x98      -80.441792
# Mily Client    -80.287508
# Claudiadaamn   -80.327160
# el_pitynq      -80.432032
# Imi_rguez      -80.318098
# valenmachp     -80.304068
# Omayrarod_03   -80.277471

# %%
import pandas as pd
import gmaps
from datetime import datetime
from ipywidgets.embed import embed_minimal_html
apikey = 'AIzaSyAdzwCpBzLDrhbtsZbFUDNKPJA0zIpshic'
now = datetime.now()


start = (25.86313861266461, -80.247161730114)
end = start


# read file
df = pd.read_csv('BreakfastFiestaOrderLog_latlong.csv', usecols = ['Cliente', 'Orden', 'Delivery Address', 'Latitude', 'Longitude'], index_col='Cliente')

# remove all orders that will be picked up
df = df[~df['Delivery Address'].isin(['Pickup'])]

# drop blank cells
df = df.dropna()

df = df.head(22)



waypoints = list(zip(df['Latitude'],df['Longitude']))

gmaps.configure(api_key=apikey)

fig = gmaps.figure()

layer = gmaps.directions.Directions(start, end, waypoints = waypoints, optimize_waypoints=True, mode='car', api_key=apikey, departure_time=now)

fig.add_layer(layer)
fig

embed_minimal_html('export.html', views=[fig])
